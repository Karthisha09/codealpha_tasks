# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Downloads/titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
import seaborn as sns

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, cmap="YlGnBu", annot=True, fmt=".2f")
plt.show()

# %%
data.shape
# Out:
# (418, 12)

# %%
from sklearn.model_selection import train_test_split
train,test=train_test_split(data, random_state=0)
train
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 208         1100         1       1              Rosenbaum, Miss. Edith Louise
# 56           948         0       3                            Cor, Mr. Bartol
# 8            900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 315         1207         1       3                       Hagardon, Miss. Kate
# 155         1047         0       3                       Duquemin, Mr. Joseph
# ..           ...       ...     ...                                        ...
# 323         1215         0       1                         Rowe, Mr. Alfred G
# 192         1084         0       3          van Billiard, Master. Walter John
# 117         1009         1       3            Sandstrom, Miss. Beatrice Irene
# 47           939         0       3                   Shaughnessy, Mr. Patrick
# 172         1064         0       3                   Dyker, Mr. Adolf Fredrik
#
# ...

# %%
data['Survived'] = data['Survived'].astype(str)
data['Pclass'] = data['Pclass'].astype(str)

plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', hue='Pclass', data=data, palette='viridis')
plt.title('Survival Count by Pclass')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', hue='Sex', data=data, palette='muted')
plt.title('Survival Count by Sex')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Pclass', hue='Sex', data=data, palette='deep', hue_order=['male', 'female'], dodge=True)
plt.title('Passenger Count by Pclass and Sex')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.show()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313 entries, 208 to 172
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  313 non-null    int64
#  1   Survived     313 non-null    int64
#  2   Pclass       313 non-null    int64
#  3   Name         313 non-null    object
#  4   Sex          313 non-null    object
#  5   Age          252 non-null    float64
#  6   SibSp        313 non-null    int64
#  7   Parch        313 non-null    int64
#  8   Ticket       313 non-null    object
#  9   Fare         312 non-null    float64
#  10  Cabin        66 non-null     object
#  11  Embarked     313 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 31.8+ KB

# %%
train = train.drop(['Ticket'], axis=1) 
test = test.drop(['Ticket'], axis=1)

# %%
train = train.drop(['Cabin'], axis=1) 
test = test.drop(['Cabin'], axis=1)

# %%
train = train.fillna({"Embarked": "S"})

# %%
mean_age = data['Age'].mean()
data['Age'] = data['Age'].fillna(mean_age)

# %%
sex_mapping = {"male": 0, "female": 1} 
train['Sex'] = train['Sex'].map(sex_mapping) 
test['Sex'] = test['Sex'].map(sex_mapping) 
  
embarked_mapping = {"S": 1, "C": 2, "Q": 3} 
train['Embarked'] = train['Embarked'].map(embarked_mapping) 
test['Embarked'] = test['Embarked'].map(embarked_mapping)

# %%
from sklearn.model_selection import train_test_split 
predictors = train.drop(['Survived', 'PassengerId'], axis=1) 
target = train["Survived"] 
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size=0.3, random_state=0)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 260 to 322
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    219 non-null    int64
#  1   Sex       219 non-null    int64
#  2   Age       183 non-null    float64
#  3   SibSp     219 non-null    int64
#  4   Parch     219 non-null    int64
#  5   Fare      218 non-null    float64
#  6   Embarked  219 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 13.7 KB

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
x_train_imputed = imputer.fit_transform(x_train)

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import accuracy_score 
  
randomforest = RandomForestClassifier(random_state=0) 
randomforest.fit(x_train_imputed, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
x_val_imputed = imputer.fit_transform(x_val)
y_val_pred = randomforest.predict(x_val_imputed)

acc_randomforest = round(accuracy_score(y_val_pred, y_val) * 100, 2)
print(f"Accuracy on validation set: {acc_randomforest}%")
# Out:
# Accuracy on validation set: 100.0%
